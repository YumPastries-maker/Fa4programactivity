# %% [markdown]
# <a href="https://colab.research.google.com/github/YumPastries-maker/Fa4programactivity/blob/main/Fa4program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for num in range(1, 21):
  if num % 2 == 0:
    continue
  print(num)

# %%
correct_password = "LeonS.Kennedy"

while True:
  user_input = input("Enter the password: ")
  if user_input == correct_password:
    print("Password is correct")
    break
  else:
    print("Password is incorrect")

# %%
for num in range(1, 10):
  if num == 4:
    continue
  if num == 6:
    pass
  if num == 8:
    break

  print(num)
